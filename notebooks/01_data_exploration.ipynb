# %% [markdown]
# # 01 — AMLSim data exploration
#
# Load AMLSim CSV, inspect distributions, sanity-check fraud labels.
#
# Wire when Day 1 ingestion is done. Suggested first cell:
#
# ```python
# import pandas as pd
# df = pd.read_csv('../data/raw/amlsim/transactions.csv')
# df.head()
# ```
